# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: black; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: cyan; padding: 20px; border-radius: 20px; border: 7px solid #2ca02c; width: 95%;">
#   <span style="font-weight: bold; color: #ff7f0e; animation: pulse 2s infinite;"></span>RSNA 2024 |
#   <span style="font-style: italic; color: #2ca02c; animation: pulse 2s infinite;"> Lumbar Spine Degenerative |</span> Classification
#
# </p>

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: white; font-size:100%; text-align:left">
#
# <h3 align="center"><font color='#DAA520'>💡 What is Degenerative Spine Disease? Treatment, Risk, and Conditions :</font></h3>
#
# The spine supports the human way of living and without it, normal functioning would become hard. That is why an issue with the spine that is as serious as degenerative spine disease cannot be taken lightly. This article will examine the conditions of degenerative spine disease, the risks, and the possible treatment options.
#
# **What is Degenerative Spine Disease?**: Degenerative spine diseases involve the gradual loss of normal function and structure of the spine. Although mostly caused by aging, factors like tumors, arthritis, and infections can also exacerbate or cause it. The pressure on the nerve roots and the spinal cord due to degeneration can result from:
#     Spinal stenosis: When the spinal canal starts narrowing
#     Herniated or slipped discs
#     Osteoarthritis: A condition where the cartilage in the spinal cord starts breaking down
#
# **Symptoms of Degenerative Spine Disease**: Listed below are a few symptoms that can indicate degenerative spinal disease:
#
# ![Degenerative-Disc-Disease.jpg](attachment:34f3e4f5-86a5-4038-9ffb-b569261556ca.jpg)
#
# Limited motion
# Sharp or chronic pain
# Pain during movement or while resting
# Deformity of the spine
# Nerve injuries like loss of senses, weakness, problems related to bladder or bowel functions, or sexual dysfunction.
#
# **Diagnosis of Degenerative Spine Disease**: The diagnosis of degenerative spine disease begins when an individual realizes there is a problem and decides to visit a doctor.
#
# X-ray: To study the backbone.
# Magnetic Resonance Imaging (MRI): To view the discs, nerves, and spinal cord space.
# Computed Tomography (CT) scan: Used if there are inconsistencies between symptoms and MRI results.
# Discograms: Used to determine if a patient’s pain is due to a damaged spinal disc.
#
# **Treatment of Degenerative Spine Disease**: ![2661274.jpg](attachment:296ca049-ef68-4a31-a571-e9029ef8af70.jpg)The treatment of degenerative spine diseases is not uniform and depends on the severity and type of condition. In many cases, surgery is not required and non-surgical treatment options can be used. Such treatments involve:
#
# Medication
# Exercises to improve flexibility and muscle strength
# Braces
# To alleviate pain, doctors may prescribe pain medicine or steroids administered in a minimally invasive manner, usually using an epidural injection. In cases involving spinal stenosis or herniated discs, surgery may be required.

# %% [markdown]
# <div style="padding: 35px;color:white;margin:10;font-size:200%;text-align:center;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://images.pexels.com/photos/7078619/pexels-photo-7078619.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1)"><b><span style='color:black'>Getting Started </span></b> </div>
# <br>
# The aim of this project is to develop a model for detecting and classifying degenerative spine conditions accurately. This involves various steps such as data understanding and preprocessing, model development, training strategy, evaluation, submission, and documentation and reporting.
#
# <br>
#
#
# <br>
# <b><span style='color:#16C2D5'>|</span> Data Understanding and Preprocessing</b>
# <br>
# 1. Data Overview
# Training Labels (train.csv): Contains study IDs and corresponding severity levels (Normal/Mild, Moderate, Severe) for each condition and spinal level.
# Label Coordinates (train_label_coordinates.csv): Provides the location (x, y) of the labeled conditions within each MRI image slice.
# Imagery Data (train_images/): MRI images in DICOM format, organized by study and series.
# Series Descriptions (train_series_descriptions.csv): Contains information about the orientation and type of each MRI series.
# 2. Preprocessing Steps
# DICOM to Array Conversion: Convert DICOM files to numerical arrays for analysis.
# Normalization: Standardize the pixel values for consistency.
# Coordinate Mapping: Use train_label_coordinates.csv to extract regions of interest (ROIs) from the MRI slices based on provided coordinates.
# Data Augmentation: Implement augmentation techniques like rotation, flipping, and scaling to increase dataset variability and robustness of the model.
# <br>
# <b><span style='color:#16C2D5'>|</span> Model Development</b>
# <br>
# 1. Model Architecture
# Backbone: Utilize a pre-trained convolutional neural network (CNN) such as ResNet, EfficientNet, or DenseNet, known for strong performance in medical image analysis.
# Custom Layers: Add layers for fine-tuning, including:
# Global Average Pooling
# Fully Connected Layers with dropout for regularization
# Softmax output layer for multi-class classification
# 2. Multi-Task Learning
# Multi-Output Model: Create a multi-output model to predict severity levels for each of the five conditions across all intervertebral disc levels (L1/L2 to L5/S1).
# <br>
# <b><span style='color:#16C2D5'>|</span> Training Strategy</b>
# <br>
# 1. Loss Function
# Weighted Categorical Cross-Entropy Loss: Handle class imbalance with weights specified as 1 for Normal/Mild, 2 for Moderate, and 4 for Severe.
# 2. Optimizer
# Adam Optimizer: Use with a learning rate scheduler to dynamically adjust learning rates.
# 3. Validation Strategy
# K-Fold Cross-Validation: Implement to ensure robustness and generalization of the model.
# <br>
# <b><span style='color:#16C2D5'>|</span> Evaluation</b>
# <br>
# 1. Metrics
# Primary Metric: Sample-weighted log loss.
# Additional Metrics: Track accuracy, precision, recall, and F1-score for each condition and severity level.
# 2. Post-Processing
# Techniques: Apply ensembling and calibration of predicted probabilities to improve performance.
# <br>
# <b><span style='color:#16C2D5'>|</span> Submission</b>
# <br>
# 1. Prediction Format
# Generate Predictions: In the required format—a CSV with row IDs and probabilities for each severity level (Normal/Mild, Moderate, Severe).
# 2. Handling Missing Data
# Ensure Predictions: For all possible rows, even if some vertebrae are not visible in the images.
# <br>
# <b><span style='color:#16C2D5'>|</span> Documentation and Reporting</b>
# <br>
# 1. Documentation
# Comprehensive Documentation: Maintain of preprocessing steps, model architecture, training process, and evaluation metrics.
# 2. Reporting
# Prepare Report: Summarizing the methodology, results, and potential improvements, highlighting the impact of different preprocessing and modeling choices on performance.
# <br>
# <b><span style='color:#16C2D5'>|</span> Tools and Libraries</b>
# <br>
# Data Handling: Pandas, NumPy
# Image Processing: OpenCV, PIL, pydicom
# Deep Learning: TensorFlow/Keras or PyTorch
# Visualization: Matplotlib, Seaborn
# Model Evaluation: Scikit-learn
# <br>
# <b><span style='color:#16C2D5'>|</span> Next Steps</b>
# <br>
# Initial Setup
# Download and Explore Dataset: Understand the structure and contents of the data.
# Set Up Environment: With necessary libraries.
# Data Preprocessing
# Implement and Test DICOM to Array Conversion.
# Extract and Visualize ROIs: Based on coordinates.
# Model Prototyping
# Build a Simple CNN Model: Test on a subset of the data.
# Iterate and Refine: Based on initial results.
# Full Model Training
# Train Final Model: With the entire dataset.
# Validate and Tune Hyperparameters.
# Final Evaluation and Submission
# Evaluate Model: On the test set.
# Generate and Submit Predictions: In the required format.

# %% [markdown]
# <div class="alert alert-success">
#     <h1 align="center" style="color:darkgoldenrod;">Importing Libraries</h1>
#
# </div>

# %%
import numpy as np
import pandas as pd
import os
import time
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import pydicom as dicom
import pydicom
import json
import glob
import collections
from pydicom.pixel_data_handlers.util import apply_voi_lut
import cv2
from skimage import measure
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import plotly.graph_objects as go
import random
from glob import glob
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: black; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: black; padding: 20px; border-radius: 20px; border: 7px solid cyan; width: 95%;">
#   <span style="font-weight: bold; color: blue; animation: pulse 2s infinite;">📉Exploratory</span>
#   <span style="font-style: italic; color: #2ca02c; animation: pulse 2s infinite;"> Data Analysis(EDA)  📊</span>
# </p>

# %% [markdown]
# <style>
# @keyframes pulse {
#   0% {
#     transform: scale(1);
#   }
#   50% {
#     transform: scale(1.1);
#   }
#   100% {
#     transform: scale(1);
#   }
# }
# </style>
#
# <div style="text-align: center; font-size: 200%; font-family: Arial, sans-serif;">
#   <b>
#     <span style='color:#ff7f0e'>Load & </span>
#     <span style='color:red'>|</span>
#     <span style='color:#2ca02c; font-style: italic; animation: pulse 2s infinite;'>|Read Data</span>
#   </b>
# </div>

# %%
"/kaggle/input/rsna-2024-lumbar-spine-degenerative-classification"+"/sdsds"
# Out:
# '/kaggle/input/rsna-2024-lumbar-spine-degenerative-classification/sdsds'

# %%
base_folder = "/kaggle/input/rsna-2024-lumbar-spine-degenerative-classification"
label_coordinates_df = pd.read_csv(base_folder+'/train_label_coordinates.csv')
train_series = pd.read_csv(base_folder+'/train_series_descriptions.csv')
df_train = pd.read_csv(base_folder+'/train.csv')
df_sub = pd.read_csv(base_folder+'/sample_submission.csv')
test_series = pd.read_csv(base_folder+'/test_series_descriptions.csv')

# %%
label_coordinates_df.head()
# Out:
#    study_id  series_id  instance_number              condition  level  \
# 0   4003253  702807833                8  Spinal Canal Stenosis  L1/L2
# 1   4003253  702807833                8  Spinal Canal Stenosis  L2/L3
# 2   4003253  702807833                8  Spinal Canal Stenosis  L3/L4
# 3   4003253  702807833                8  Spinal Canal Stenosis  L4/L5
# 4   4003253  702807833                8  Spinal Canal Stenosis  L5/S1
#
#             x           y
# 0  322.831858  227.964602
# 1  320.571429  295.714286
# 2  323.030303  371.818182
# 3  335.292035  427.327434
# 4  353.415929  483.964602

# %%
train_series.head()
# Out:
#    study_id   series_id series_description
# 0   4003253   702807833   Sagittal T2/STIR
# 1   4003253  1054713880        Sagittal T1
# 2   4003253  2448190387           Axial T2
# 3   4646740  3201256954           Axial T2
# 4   4646740  3486248476        Sagittal T1

# %%
train_series.study_id.nunique() #1975
# Out:
# 1975

# %%
train_series.series_id.nunique() #6294
# Out:
# 6294

# %%
label_coordinates_df.shape
# Out:
# (48692, 7)

# %%
df_train.head(10)
# Out:
#    study_id spinal_canal_stenosis_l1_l2 spinal_canal_stenosis_l2_l3  \
# 0   4003253                 Normal/Mild                 Normal/Mild
# 1   4646740                 Normal/Mild                 Normal/Mild
# 2   7143189                 Normal/Mild                 Normal/Mild
# 3   8785691                 Normal/Mild                 Normal/Mild
# 4  10728036                 Normal/Mild                 Normal/Mild
# 5  11340341                 Normal/Mild                 Normal/Mild
# 6  11943292                 Normal/Mild                 Normal/Mild
# 7  13317052                 Normal/Mild                 Normal/Mild
# 8  22191399                 Normal/Mild                 Normal/Mild
# 9  26342422                 Normal/Mild                 Normal/Mild
#
#   spinal_canal_stenosis_l3_l4 spinal_canal_stenosis_l4_l5  \
# 0                 Normal/Mild                 Normal/Mild
# 1                    Moderate                      Severe
# 2                 Normal/Mild                 Normal/Mild
# 3                 Normal/Mild                 Normal/Mild
# 4                 Normal/Mild                 Normal/Mild
# 5                 Normal/Mild                 Normal/Mild
# 6                 Normal/Mild                 Normal/Mild
# 7                 Normal/Mild                 Normal/Mild
# 8                 Normal/Mild                      Severe
# 9                 Normal/Mild                 Normal/Mild
#
#   spinal_canal_stenosis_l5_s1 left_neural_foraminal_narrowing_l1_l2  \
# 0                 Normal/Mild                           Normal/Mild
# 1                 Normal/Mild                           Normal/Mild
# 2                 Normal/Mild                           Normal/Mild
# 3                 Normal/Mild                           Normal/Mild
# 4                 Normal/Mild                           Normal/Mild
# 5                 Normal/Mild                           Normal/Mild
# 6                 Normal/Mild                           Normal/Mild
# 7                 Normal/Mild                           Normal/Mild
# 8                 Normal/Mild                           Normal/Mild
# 9                 Normal/Mild                           Normal/Mild
#
#   left_neural_foraminal_narrowing_l2_l3 left_neural_foraminal_narrowing_l3_l4  \
# 0                           Normal/Mild                           Normal/Mild
# 1                           Normal/Mild                           Normal/Mild
# 2                           Normal/Mild                           Normal/Mild
# 3                           Normal/Mild                           Normal/Mild
# 4                           Normal/Mild                           Normal/Mild
# 5                           Normal/Mild                           Normal/Mild
# 6                           Normal/Mild                           Normal/Mild
# 7                           Normal/Mild                           Normal/Mild
# 8                           Normal/Mild                           Normal/Mild
# 9                           Normal/Mild                           Normal/Mild
#
#   left_neural_foraminal_narrowing_l4_l5  ... left_subarticular_stenosis_l1_l2  \
# 0                              Moderate  ...                      Normal/Mild
# 1                              Moderate  ...                      Normal/Mild
# 2                           Normal/Mild  ...                      Normal/Mild
# 3                              Moderate  ...                      Normal/Mild
# 4                           Normal/Mild  ...                      Normal/Mild
# 5                           Normal/Mild  ...                      Normal/Mild
# 6                           Normal/Mild  ...                      Normal/Mild
# 7                              Moderate  ...                      Normal/Mild
# 8                           Normal/Mild  ...                      Normal/Mild
# 9                           Normal/Mild  ...                      Normal/Mild
#
#   left_subarticular_stenosis_l2_l3 left_subarticular_stenosis_l3_l4  \
# 0                      Normal/Mild                      Normal/Mild
# 1                      Normal/Mild                      Normal/Mild
# 2                      Normal/Mild                      Normal/Mild
# 3                      Normal/Mild                      Normal/Mild
# 4                      Normal/Mild                      Normal/Mild
# 5                      Normal/Mild                         Moderate
# 6                      Normal/Mild                      Normal/Mild
# 7                      Normal/Mild                      Normal/Mild
# 8                      Normal/Mild                      Normal/Mild
# 9                      Normal/Mild                      Normal/Mild
#
#   left_subarticular_stenosis_l4_l5 left_subarticular_stenosis_l5_s1  \
# 0                         Moderate                      Normal/Mild
# 1                           Severe                      Normal/Mild
# 2                      Normal/Mild                      Normal/Mild
# 3                      Normal/Mild                      Normal/Mild
# 4                      Normal/Mild                      Normal/Mild
# 5                         Moderate                      Normal/Mild
# 6                      Normal/Mild                         Moderate
# 7                      Normal/Mild                      Normal/Mild
# 8                         Moderate                         Moderate
# 9                      Normal/Mild                      Normal/Mild
#
#   right_subarticular_stenosis_l1_l2 right_subarticular_stenosis_l2_l3  \
# 0                       Normal/Mild                       Normal/Mild
# 1                       Normal/Mild                          Moderate
# 2                       Normal/Mild                       Normal/Mild
# 3                       Normal/Mild                       Normal/Mild
# 4                       Normal/Mild                       Normal/Mild
# 5                       Normal/Mild                       Normal/Mild
# 6                       Normal/Mild                       Normal/Mild
# 7                       Normal/Mild                       Normal/Mild
# 8                       Normal/Mild                       Normal/Mild
# 9                       Normal/Mild                       Normal/Mild
#
#   right_subarticular_stenosis_l3_l4 right_subarticular_stenosis_l4_l5  \
# 0                       Normal/Mild                       Normal/Mild
# 1                          Moderate                          Moderate
# 2                       Normal/Mild                       Normal/Mild
# 3                       Normal/Mild                       Normal/Mild
# 4                       Normal/Mild                          Moderate
# 5                          Moderate                          Moderate
# 6                       Normal/Mild                       Normal/Mild
# 7                          Moderate                          Moderate
# 8                       Normal/Mild                            Severe
# 9                       Normal/Mild                       Normal/Mild
#
#   right_subarticular_stenosis_l5_s1
# 0                       Normal/Mild
# 1                       Normal/Mild
# 2                       Normal/Mild
# 3                       Normal/Mild
# 4                       Normal/Mild
# 5                       Normal/Mild
# 6                       Normal/Mild
# 7                          Moderate
# 8                          Moderate
# 9                       Normal/Mild
#
# [10 rows x 26 columns]

# %%
print(f'df_train.shape = {df_train.shape}')
print(f'df_train.study_id.nunique() = {df_train.study_id.nunique()}')
# Her study_id unique!!
# Out:
# df_train.shape = (1975, 26)
# df_train.study_id.nunique() = 1975

# %%
df_sub.head(10) #sample submission dataframe
# Out:
#                                            row_id  normal_mild  moderate  \
# 0  44036939_left_neural_foraminal_narrowing_l1_l2     0.333333  0.333333
# 1  44036939_left_neural_foraminal_narrowing_l2_l3     0.333333  0.333333
# 2  44036939_left_neural_foraminal_narrowing_l3_l4     0.333333  0.333333
# 3  44036939_left_neural_foraminal_narrowing_l4_l5     0.333333  0.333333
# 4  44036939_left_neural_foraminal_narrowing_l5_s1     0.333333  0.333333
# 5       44036939_left_subarticular_stenosis_l1_l2     0.333333  0.333333
# 6       44036939_left_subarticular_stenosis_l2_l3     0.333333  0.333333
# 7       44036939_left_subarticular_stenosis_l3_l4     0.333333  0.333333
# 8       44036939_left_subarticular_stenosis_l4_l5     0.333333  0.333333
# 9       44036939_left_subarticular_stenosis_l5_s1     0.333333  0.333333
#
#      severe
# 0  0.333333
# 1  0.333333
# 2  0.333333
# 3  0.333333
# 4  0.333333
# 5  0.333333
# 6  0.333333
# 7  0.333333
# 8  0.333333
# 9  0.333333

# %%
print(f'df_sub.shape = {df_sub.shape}')
print(f'df_sub.row_id.nunique() = {df_sub.row_id.nunique()}')
# Out:
# df_sub.shape = (25, 4)
# df_sub.row_id.nunique() = 25

# %%
test_series.head(10)
# Out:
#    study_id   series_id series_description
# 0  44036939  2828203845        Sagittal T1
# 1  44036939  3481971518           Axial T2
# 2  44036939  3844393089   Sagittal T2/STIR

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: black; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: white; padding: 20px; border-radius: 20px; border: 7px solid cyan; width: 95%;">
#   <span style="font-weight: bold; color: blue; animation: pulse 2s infinite;">🎥Loading </span>
#   <span style="font-style: italic; color: #2ca02c; animation: pulse 2s infinite;"> Images 🖼</span>
# </p>

# %% [markdown]
# <div style="text-align: center; font-family: Arial, sans-serif; font-size: 150%;">
#     <b>
#         <span style='color:#ff7f0e'>What Does </span>
#         <span style='color:red'>|</span>
#         <span style='color:#2ca02c; font-style: italic; animation: pulse 2s infinite;'>Data Talks</span>
#     </b>
# </div>

# %%
folder_path = '/kaggle/input/rsna-2024-lumbar-spine-degenerative-classification/train_images/100206310/1012284084'
dicom_files = [f for f in os.listdir(folder_path) if f.endswith('.dcm')]

# %%
len(dicom_files)
# Out:
# 60

# %%
type(dicom_files[0])
# Out:
# str

# %%
len(dicom_files) # Only for 1 study_id, series_id such that train_images/100206310/1012284084
# Out:
# 60

# %%
folder_path = '/kaggle/input/rsna-2024-lumbar-spine-degenerative-classification/train_images/100206310/1012284084'
dicom_files = [f for f in os.listdir(folder_path) if f.endswith('.dcm')] 
# dicom_files is not change in this line
label_coordinates_df = pd.read_csv('/kaggle/input/rsna-2024-lumbar-spine-degenerative-classification/train_label_coordinates.csv')

# %%
dicom_files
# Out:
# ['12.dcm',
#  '18.dcm',
#  '9.dcm',
#  '22.dcm',
#  '25.dcm',
#  '39.dcm',
#  '45.dcm',
#  '14.dcm',
#  '11.dcm',
#  '44.dcm',
#  '24.dcm',
#  '34.dcm',
#  '29.dcm',
#  '23.dcm',
#  '41.dcm',
#  '35.dcm',
#  '59.dcm',
#  '56.dcm',
#  '60.dcm',
#  '10.dcm',
#  '46.dcm',
#  '28.dcm',
#  '43.dcm',
#  '50.dcm',
#  '37.dcm',
#  '17.dcm',
#  '30.dcm',
#  '1.dcm',
#  '15.dcm',
#  '2.dcm',
#  '52.dcm',
#  '48.dcm',
#  '36.dcm',
#  '8.dcm',
#  '7.dcm',
#  '53.dcm',
#  '55.dcm',
#  '21.dcm',
#  '49.dcm',
#  '51.dcm',
#  '33.dcm',
#  '5.dcm',
#  '4.dcm',
#  '58.dcm',
#  '42.dcm',
#  '54.dcm',
#  '47.dcm',
#  '31.dcm',
#  '38.dcm',
#  '19.dcm',
#  '57.dcm',
#  '27.dcm',
#  '6.dcm',
#  '16.dcm',
#  '20.dcm',
#  '40.dcm',
#  '3.dcm',
#  '32.dcm',
#  '26.dcm',
#  '13.dcm']

# %%
label_coordinates_df
# Out:
#          study_id   series_id  instance_number  \
# 0         4003253   702807833                8
# 1         4003253   702807833                8
# 2         4003253   702807833                8
# 3         4003253   702807833                8
# 4         4003253   702807833                8
# ...           ...         ...              ...
# 48687  4290709089  4237840455               11
# 48688  4290709089  4237840455               12
# 48689  4290709089  4237840455               12
# 48690  4290709089  4237840455               12
# 48691  4290709089  4237840455               12
#
#                              condition  level           x           y
# 0                Spinal Canal Stenosis  L1/L2  322.831858  227.964602
# 1                Spinal Canal Stenosis  L2/L3  320.571429  295.714286
# 2                Spinal Canal Stenosis  L3/L4  323.030303  371.818182
# 3                Spinal Canal Stenosis  L4/L5  335.292035  427.327434
# 4                Spinal Canal Stenosis  L5/S1  353.415929  483.964602
# ...                                ...    ...         ...         ...
# 48687  Left Neural Foraminal Narrowing  L1/L2  219.465940   97.831063
# 48688  Left Neural Foraminal Narrowing  L2/L3  205.340599  140.207084
# 48689  Left Neural Foraminal Narrowing  L3/L4  202.724796  181.013624
# 48690  Left Neural Foraminal Narrowing  L4/L5  202.933333  219.733333
# 48691  Left Neural Foraminal Narrowing  L5/S1  211.813953  259.534884
#
# [48692 rows x 7 columns]

# %%
label_coordinates_df.series_id.nunique()
# Out:
# 6291

# %%
label_coordinates_df.study_id.nunique()
# Out:
# 1974

# %%
study_id = folder_path.split('/')[-2]

# %%
study_id
# Out:
# '100206310'

# %%
study_label_coordinates = label_coordinates_df[label_coordinates_df['study_id'] == int(study_id)] 
#filter label_coordinates_df for study_id!

# %%
study_label_coordinates.shape
# Out:
# (25, 7)

# %%
# initialize
filtered_dicom_files = []
filtered_label_coordinates = []

# %%
study_label_coordinates
# Out:
#        study_id   series_id  instance_number  \
# 1112  100206310  1012284084               20
# 1113  100206310  1012284084               20
# 1114  100206310  1012284084               28
# 1115  100206310  1012284084               28
# 1116  100206310  1012284084               37
# 1117  100206310  1012284084               37
# 1118  100206310  1012284084               46
# 1119  100206310  1012284084               46
# 1120  100206310  1012284084               55
# 1121  100206310  1012284084               55
# 1122  100206310  1792451510                9
# 1123  100206310  1792451510                9
# 1124  100206310  1792451510                9
# 1125  100206310  1792451510                9
# 1126  100206310  1792451510                9
# 1127  100206310  2092806862                4
# 1128  100206310  2092806862                4
# 1129  100206310  2092806862                5
# 1130  100206310  2092806862                6
# 1131  100206310  2092806862                6
# 1132  100206310  2092806862               12
# 1133  100206310  2092806862               12
# 1134  100206310  2092806862               12
# 1135  100206310  2092806862               13
# 1136  100206310  2092806862               13
#
#                              condition  level           x           y
# 1112        Left Subarticular Stenosis  L1/L2  180.355677  165.034200
# 1113       Right Subarticular Stenosis  L1/L2  145.120536  162.285714
# 1114        Left Subarticular Stenosis  L2/L3  177.729138  160.218878
# 1115       Right Subarticular Stenosis  L2/L3  145.691964  160.000000
# 1116        Left Subarticular Stenosis  L3/L4  173.351573  158.467852
# 1117       Right Subarticular Stenosis  L3/L4  147.406250  161.142857
# 1118        Left Subarticular Stenosis  L4/L5  168.536252  156.279070
# 1119       Right Subarticular Stenosis  L4/L5  146.263393  160.000000
# 1120        Left Subarticular Stenosis  L5/S1  167.660739  157.154583
# 1121       Right Subarticular Stenosis  L5/S1  145.120536  159.428571
# 1122             Spinal Canal Stenosis  L1/L2  240.298788  151.518293
# 1123             Spinal Canal Stenosis  L2/L3  229.030495  203.030488
# 1124             Spinal Canal Stenosis  L3/L4  225.810983  257.762195
# 1125             Spinal Canal Stenosis  L4/L5  231.445129  316.518293
# 1126             Spinal Canal Stenosis  L5/S1  247.542690  360.786585
# 1127  Right Neural Foraminal Narrowing  L4/L5  253.393075  278.680244
# 1128  Right Neural Foraminal Narrowing  L5/S1  252.350305  320.391039
# 1129  Right Neural Foraminal Narrowing  L3/L4  252.350305  235.926680
# 1130  Right Neural Foraminal Narrowing  L1/L2  265.906314  146.248473
# 1131  Right Neural Foraminal Narrowing  L2/L3  256.521385  186.916497
# 1132   Left Neural Foraminal Narrowing  L2/L3  260.177602  191.705532
# 1133   Left Neural Foraminal Narrowing  L4/L5  249.241774  274.786914
# 1134   Left Neural Foraminal Narrowing  L5/S1  258.806490  319.853318
# 1135   Left Neural Foraminal Narrowing  L1/L2  270.342250  148.221459
# 1136   Left Neural Foraminal Narrowing  L3/L4  250.176889  234.398551

# %%
for dicom_file in dicom_files:
    instance_number = int(dicom_file.split('.')[0]) # the number in the name of dcm file
    corresponding_coordinates = study_label_coordinates[study_label_coordinates['instance_number'] == instance_number]
    if not corresponding_coordinates.empty:
        filtered_dicom_files.append(dicom_file)
        filtered_label_coordinates.append(corresponding_coordinates)

# %%
fig, axs = plt.subplots(1, 4, figsize=(20, 5))
second_row_index = 1
second_row_images = filtered_dicom_files[second_row_index : second_row_index + 4]
second_row_coordinates = filtered_label_coordinates[second_row_index : second_row_index + 4]

for i, (dicom_file, label_coordinates) in enumerate(zip(second_row_images, second_row_coordinates)):
    dicom_file_path = os.path.join(folder_path, dicom_file)
    dicom_data = pydicom.dcmread(dicom_file_path)
    image = dicom_data.pixel_array   
    axs[i].imshow(image, cmap='gray')
    axs[i].set_title(f'DICOM Image - {dicom_file}')
    axs[i].axis('off')   
    for _, row in label_coordinates.iterrows():
        axs[i].plot(row['x'], row['y'], 'ro', markersize=5) 
        
#plt.tight_layout()
#plt.show()

# %%
df_train.head()
# Out:
#    study_id spinal_canal_stenosis_l1_l2 spinal_canal_stenosis_l2_l3  \
# 0   4003253                 Normal/Mild                 Normal/Mild
# 1   4646740                 Normal/Mild                 Normal/Mild
# 2   7143189                 Normal/Mild                 Normal/Mild
# 3   8785691                 Normal/Mild                 Normal/Mild
# 4  10728036                 Normal/Mild                 Normal/Mild
#
#   spinal_canal_stenosis_l3_l4 spinal_canal_stenosis_l4_l5  \
# 0                 Normal/Mild                 Normal/Mild
# 1                    Moderate                      Severe
# 2                 Normal/Mild                 Normal/Mild
# 3                 Normal/Mild                 Normal/Mild
# 4                 Normal/Mild                 Normal/Mild
#
#   spinal_canal_stenosis_l5_s1 left_neural_foraminal_narrowing_l1_l2  \
# 0                 Normal/Mild                           Normal/Mild
# 1                 Normal/Mild                           Normal/Mild
# 2                 Normal/Mild                           Normal/Mild
# 3                 Normal/Mild                           Normal/Mild
# 4                 Normal/Mild                           Normal/Mild
#
#   left_neural_foraminal_narrowing_l2_l3 left_neural_foraminal_narrowing_l3_l4  \
# 0                           Normal/Mild                           Normal/Mild
# 1                           Normal/Mild                           Normal/Mild
# 2                           Normal/Mild                           Normal/Mild
# 3                           Normal/Mild                           Normal/Mild
# 4                           Normal/Mild                           Normal/Mild
#
#   left_neural_foraminal_narrowing_l4_l5  ... left_subarticular_stenosis_l1_l2  \
# 0                              Moderate  ...                      Normal/Mild
# 1                              Moderate  ...                      Normal/Mild
# 2                           Normal/Mild  ...                      Normal/Mild
# 3                              Moderate  ...                      Normal/Mild
# 4                           Normal/Mild  ...                      Normal/Mild
#
#   left_subarticular_stenosis_l2_l3 left_subarticular_stenosis_l3_l4  \
# 0                      Normal/Mild                      Normal/Mild
# 1                      Normal/Mild                      Normal/Mild
# 2                      Normal/Mild                      Normal/Mild
# 3                      Normal/Mild                      Normal/Mild
# 4                      Normal/Mild                      Normal/Mild
#
#   left_subarticular_stenosis_l4_l5 left_subarticular_stenosis_l5_s1  \
# 0                         Moderate                      Normal/Mild
# 1                           Severe                      Normal/Mild
# 2                      Normal/Mild                      Normal/Mild
# 3                      Normal/Mild                      Normal/Mild
# 4                      Normal/Mild                      Normal/Mild
#
#   right_subarticular_stenosis_l1_l2 right_subarticular_stenosis_l2_l3  \
# 0                       Normal/Mild                       Normal/Mild
# 1                       Normal/Mild                          Moderate
# 2                       Normal/Mild                       Normal/Mild
# 3                       Normal/Mild                       Normal/Mild
# 4                       Normal/Mild                       Normal/Mild
#
#   right_subarticular_stenosis_l3_l4 right_subarticular_stenosis_l4_l5  \
# 0                       Normal/Mild                       Normal/Mild
# 1                          Moderate                          Moderate
# 2                       Normal/Mild                       Normal/Mild
# 3                       Normal/Mild                       Normal/Mild
# 4                       Normal/Mild                          Moderate
#
#   right_subarticular_stenosis_l5_s1
# 0                       Normal/Mild
# 1                       Normal/Mild
# 2                       Normal/Mild
# 3                       Normal/Mild
# 4                       Normal/Mild
#
# [5 rows x 26 columns]

# %%
df_train.shape
# Out:
# (1975, 26)

# %%
def load_dicom(path):
    dicom = pydicom.read_file(path)
    data = dicom.pixel_array
    data = data - np.min(data)
    if np.max(data) != 0:
        data = data / np.max(data)
    data = (data * 255).astype(np.uint8)
    return data

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: black; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: white; padding: 20px; border-radius: 20px; border: 7px solid cyan; width: 95%;">
#   <span style="font-weight: bold; color: blue; animation: pulse 2s infinite;">🎥Animated </span>
#   <span style="font-style: italic; color: #2ca02c; animation: pulse 2s infinite;"> View of Images 🖼</span>
# </p>

# %%
import glob
from matplotlib import animation, rc

rc('animation', html='jshtml')

def load_dicom(filename):
    ds = pydicom.dcmread(filename)
    return ds.pixel_array

def load_dicom_line(path):
    t_paths = sorted(
        glob.glob(os.path.join(path, "*")), 
        key=lambda x: int(os.path.splitext(os.path.basename(x))[0].split("-")[-1]),
    )
    images = []
    for filename in t_paths:
        data = load_dicom(filename)
        if data.max() == 0:
            continue
        images.append(data)
    return images

def create_animation(ims):
    fig = plt.figure(figsize=(6, 6))
    plt.axis('off')
    im = plt.imshow(ims[0], cmap="gray")

    def animate_func(i):
        im.set_array(ims[i])
        return [im]

    return animation.FuncAnimation(fig, animate_func, frames=len(ims), interval=1000//24)

path_to_folder = "/kaggle/input/rsna-2024-lumbar-spine-degenerative-classification/train_images/100206310/1792451510"
images = load_dicom_line(path_to_folder)
#anim = create_animation(images)
#anim

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: black; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: white; padding: 20px; border-radius: 20px; border: 7px solid cyan; width: 95%;">
#   <span style="font-weight: bold; color: blue; animation: pulse 2s infinite;">🎥Plot Histogram </span>
#   <span style="font-style: italic; color: #2ca02c; animation: pulse 2s infinite;"> Video/Images 🖼</span>
# </p>

# %%
def read_dicom_files(path_to_folder, num_files=5):
    
    files_glob = os.path.join(path_to_folder, "*.dcm")
    dicom_files = sorted(glob.glob(files_glob), key=lambda f: int(os.path.splitext(os.path.basename(f))[0].split('-')[-1]))
    num_files = len(dicom_files)
    return [pydicom.dcmread(f) for f in dicom_files[:num_files]]

def calculate_level(mean, std):
    return mean + 1.7 * std

def stats_image(image):
    noncero_pixels = image[np.nonzero(image)]
    if noncero_pixels.size == 0:
        mean = 0
        std = 0
    else:
        mean = np.mean(noncero_pixels)
        std = np.std(noncero_pixels)
    return mean, std

def image_orientation(dicom):
    rt = 'unknown'
    x1, y1, _, x2, y2, _ = [round(v) for v in dicom.ImageOrientationPatient]
    if (x1, y1, x2, y2) == (1, 0, 0, 0):
        rt = 'coronal'
    elif (x1, y1, x2, y2) == (1, 0, 0, 1):
        rt = 'axial'
    elif (x1, y1, x2, y2) == (0, 1, 0, 0):
        rt = 'sagittal'
    if rt == 'unknown':
        raise ValueError(f'unknown ImageOrientationPatient: {dicom.ImageOrientationPatient}')
    return rt

def plot_image_hist(image):
    mean, std = stats_image(image)
    pixels = image.ravel()
    noncero_pixels = pixels[np.nonzero(pixels)]
    noncero_pixels = (noncero_pixels - mean) / std
    over_threshold = np.count_nonzero(noncero_pixels > calculate_level(mean, std))
    
    fig, (axi, axh) = plt.subplots(1, 2, figsize=(20, 3), gridspec_kw={'width_ratios': [1, 4]})
    fig.suptitle(f'scan # ({over_threshold})')
    
    axh.hist(noncero_pixels, 200, range=(-5, 5))  
    axh.set_xlim(-5, 5)

    ax_limits = axh.get_ylim()
    axh.vlines(mean, ymin=ax_limits[0], ymax=ax_limits[1], colors='r', label='Mean')
    axh.vlines(mean + std, ymin=ax_limits[0], ymax=ax_limits[1], colors='g', linestyles='dotted', label='Mean + Std')
    axh.vlines(calculate_level(mean, std), ymin=ax_limits[0], ymax=ax_limits[1], colors='b', linestyles='dashed', label='Threshold')

    axi.imshow(image, cmap=plt.cm.gray)
    axi.grid(False)
    axi.axis('off')
    axh.legend()
    plt.show()

path_to_folder = "/kaggle/input/rsna-2024-lumbar-spine-degenerative-classification/train_images/1002894806/866293114"
dicom_files = read_dicom_files(path_to_folder)

if dicom_files:
    first_image = dicom_files[0].pixel_array
    plot_image_hist(first_image)
else:
    print("No DICOM files found.")

# %%
import plotly.express as px

def read_dicom_files(path_to_folder, num_files=5):
    files_glob = os.path.join(path_to_folder, "*.dcm")
    dicom_files = sorted(glob.glob(files_glob), key=lambda f: int(os.path.splitext(os.path.basename(f))[0].split('-')[-1]))
    return [pydicom.dcmread(f) for f in dicom_files[:num_files]]

def get_flair_images(dicom_files):
    images = [s.pixel_array for s in dicom_files]
    return np.array(images)
"""
path_to_folder = "/kaggle/input/rsna-2024-lumbar-spine-degenerative-classification/train_images/100206310/1012284084"
dicom_files = read_dicom_files(path_to_folder)
flair_images = get_flair_images(dicom_files)
fig = px.imshow(flair_images, animation_frame=0, binary_string=True, labels=dict(x="FLAIR Images", animation_frame="Scan"), height=800)
fig.show() """
# Out:
# '\npath_to_folder = "/kaggle/input/rsna-2024-lumbar-spine-degenerative-classification/train_images/100206310/1012284084"\ndicom_files = read_dicom_files(path_to_folder)\nflair_images = get_flair_images(dicom_files)\nfig = px.imshow(flair_images, animation_frame=0, binary_string=True, labels=dict(x="FLAIR Images", animation_frame="Scan"), height=800)\nfig.show() '

# %%
image_data = dicom_files[0].pixel_array

# %%
img_list = []
for dcm in dicom_files:
    img_list.append(dcm.pixel_array)

# %%
len(dicom_files)
# Out:
# 18

# %%
def npndarray_show(image_data):
    plt.imshow(image_data, cmap=plt.cm.gray)
    plt.show()

# %%
npndarray_show(image_data)

# %%
len(dicom_files)
# Out:
# 18

# %%
# XXXTBD 14.08.24 make a training dataset including 'image' as a column!
# XXXTBD 14.08.24: modify "read_dicom_files" so that it can read dicoms in multiple folders!
df_img = pd.DataFrame(columns=['study_id', 'series_id', 'instance_id', 'image_np'])

# %%
df_img
# Out:
# Empty DataFrame
# Columns: [study_id, series_id, instance_id, image_np]
# Index: []

# %%
def find_files(directory, file_extension):

    array = [] 

    for root, dirs, files in os.walk(directory):

        for i, file in enumerate(files):
            ind +=1
            #print(f"dirs[i] = {dirs[i]}")
            if file.endswith(file_extension):
                row = []
                file_pth_joined = os.path.join(root, file)
                filepath_split_list = file_pth_joined.split('/')
                row.append(filepath_split_list[-3])
                row.append(filepath_split_list[-2])
                row.append(file.split('.')[0])
                ds = pydicom.dcmread(file_pth_joined)
                row.append(ds.pixel_array)
                array.append(row)

            
        df_img = pd.DataFrame(array, columns = ['study_id', 'series_id', 'instance_id', 'image_np'])
        df_img.to_csv(f"/kaggle/working/chunk_.csv")

    return df_img

# %%
def find_files(directory, file_extension):
    matching_files = []
    max_ind = 5000
    ind = 0
    chunk_no = 1
    array = [] 
    # Walk through the directory and its subdirectories
    for root, dirs, files in os.walk(directory):
        #ind +=1
        #print(f"dirs = {dirs}")
        for i, file in enumerate(files):
            ind +=1
            #print(f"dirs[i] = {dirs[i]}")
            if file.endswith(file_extension):
                row = []
                file_pth_joined = os.path.join(root, file)
                #matching_files.append(file_pth_joined)
                #filepaTH = os.path.join(root, file)
                #print(f"filepaTH = {filepaTH}")
                filepath_split_list = file_pth_joined.split('/')
                
                #print(f"filepath_split_list = {filepath_split_list}")
                
                row.append(filepath_split_list[-3])
                row.append(filepath_split_list[-2])
                row.append(file.split('.')[0])
                ds = pydicom.dcmread(file_pth_joined)
                row.append(ds.pixel_array)
                array.append(row)
                #print(f"row = {row}")
            #print(f"ind = {ind}")
            if ind >= max_ind:
                df_img = pd.DataFrame(array, columns = ['study_id', 'series_id', 'instance_id', 'image_np'])
                df_img.to_csv(f"/kaggle/working/chunk_{chunk_no}.csv")
                ind = 0
                chunk_no +=1
                del df_img
                

            #df_img.loc[len(df_img)] = row
        
        
        #df_img.columns = ['study_id', 'series_id', 'instance_id', 'image_np']
    return df_img

# %%
os.getcwd()
# Out:
# '/kaggle/working'

# %%
train_data_loc = "/kaggle/input/rsna-2024-lumbar-spine-degenerative-classification/train_images" 
file_extension_dcm = ".dcm"

# %%
df_img.study_id #Index(['study_id', 'series_id', 'instance_id', 'image_np'], dtype='object')
# Out:
# Series([], Name: study_id, dtype: object)

# %%
df_img = find_files(train_data_loc, file_extension_dcm)

# %%
df_img.describe()

# %%
df_img.columns

# %%
#for img in flair_images[:5]:
#    plot_image_hist(img)

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: black; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: white; padding: 20px; border-radius: 20px; border: 7px solid cyan; width: 95%;">
#   <span style="font-weight: bold; color: blue; animation: pulse 2s infinite;">Meta Information </span>
#   <span style="font-style: italic; color: #2ca02c; animation: pulse 2s infinite;"> of Images 🖼</span>
# </p>

# %%
dicom_files[1]

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: black; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: white; padding: 20px; border-radius: 20px; border: 7px solid cyan; width: 95%;">
#   <span style="font-weight: bold; color: blue; animation: pulse 2s infinite;">3D View </span>
#   <span style="font-style: italic; color: #2ca02c; animation: pulse 2s infinite;"> of Images 🖼</span>
# </p>

# %%
def load_dicom_images(folder_path, num_images=5):
    dicom_files = sorted([os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.dcm')])[:num_images]
    images = [pydicom.dcmread(f).pixel_array for f in dicom_files]
    return np.stack(images, axis=-1)

def plot_3d(image, threshold=-300):

    verts, faces, _, _ = measure.marching_cubes(image, level=threshold)  
    
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')    
    
    mesh = Poly3DCollection(verts[faces], alpha=0.1)
    face_color = [0.5, 0.5, 1]  # light blue
    mesh.set_facecolor(face_color)
    ax.add_collection3d(mesh)
    
    ax.set_xlim(0, image.shape[0])
    ax.set_ylim(0, image.shape[1])
    ax.set_zlim(0, image.shape[2])
    
    plt.show()


folder_path = "/kaggle/input/rsna-2024-lumbar-spine-degenerative-classification/train_images/100206310/1012284084"
dicom_images = load_dicom_images(folder_path, num_images=5)
#plot_3d(dicom_images, threshold=300)

# %%
def load_dicom_images(folder_path, num_images=5):
    dicom_files = sorted([os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.dcm')])[:num_images]
    images = [pydicom.dcmread(f).pixel_array for f in dicom_files]
    return np.stack(images, axis=-1)

def plot_3d_interactive(image, threshold=-300):    
    verts, faces, _, _ = measure.marching_cubes(image, level=threshold)   
    
    fig = go.Figure(data=[
        go.Mesh3d(
            x=verts[:, 0],
            y=verts[:, 1],
            z=verts[:, 2],
            i=faces[:, 0],
            j=faces[:, 1],
            k=faces[:, 2],
            color='blue',
            opacity=0.1
        )
    ])
    
    fig.update_layout(
        scene=dict(
            xaxis=dict(visible=True),
            yaxis=dict(visible=True),
            zaxis=dict(visible=True)
        ),
        width=800,
        height=800,
        title="Interactive 3D DICOM Image Visualization"
    )
    
    fig.show()


folder_path = "/kaggle/input/rsna-2024-lumbar-spine-degenerative-classification/train_images/1002894806/866293114"
dicom_images = load_dicom_images(folder_path, num_images=5)
#plot_3d_interactive(dicom_images, threshold=100)

# %%
from mpl_toolkits.mplot3d import Axes3D

def plot_3d_image(image):   
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    rows, cols = image.shape
    x, y = np.meshgrid(np.arange(cols), np.arange(rows))
    ax.plot_surface(x, y, image, cmap='viridis', edgecolor='none')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Intensity')
    ax.set_title('3D Plot of Image')
    plt.show()
    
#plot_3d_image(flair_images[0])

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: black; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: white; padding: 20px; border-radius: 20px; border: 7px solid cyan; width: 95%;">
#   <span style="font-weight: bold; color: blue; animation: pulse 2s infinite;">Simple Data preperation </span>
#   <span style="font-style: italic; color: #2ca02c; animation: pulse 2s infinite;"> Training/Prediction 🖼</span>
# </p>

# %%
df_sub.head()

# %%
df_sub.shape,test_series.shape,train_series.shape,label_coordinates_df.shape,df_train.shape

# %%
#test_series.head()

# %%
#train_series.head()

# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: white; font-size:100%; text-align:left">
#
# <h3 align="center"><font color='#DAA520'>💡 What below code is doing we can look into trhough steps :</font></h3>
#
# **Step 1: Reshape and Process Training Data**
# here we are trying to Convert df_train (i have refered one of the above data as) from wide to long format using pd.melt, keeping study_id intact and creating condition_level and severity columns. Then further splitting & Extracting the  conditions and level from the condition_level column by splitting it at the underscores then Using LabelEncoder to convert the severity labels into numeric format.
#
# **Step 2: Creating a Target for Training**
# Creating the required data  as X_train with features (study_id, condition, level) and y_train with the target (severity_encoded).Applying encoding to the condition and level columns in X_train.
#
# **Step 3: Creating a Test Data**
# Creating a list of test_rows by iterating over each row in test_series and generating all combinations of condition and level for each
# study_id and then Converting test_rows to a DataFrame X_test, then encoding and matching with train and filling any missing values

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier


df_train_melted = df_train.melt(id_vars=['study_id'], var_name='condition_level', value_name='severity')
df_train_melted[['condition', 'level']] = df_train_melted['condition_level'].str.rsplit('_', n=1, expand=True)
le_severity = LabelEncoder()
df_train_melted['severity_encoded'] = le_severity.fit_transform(df_train_melted['severity'])
X_train = df_train_melted[['study_id', 'condition', 'level']]
y_train = df_train_melted['severity_encoded']
X_train = pd.get_dummies(X_train, columns=['condition', 'level'])
test_rows = []
for _, row in test_series.iterrows():
    for condition in ['left_neural_foraminal_narrowing', 'right_neural_foraminal_narrowing', 'left_subarticular_stenosis', 'right_subarticular_stenosis', 'spinal_canal_stenosis']:
        for level in ['l1_l2', 'l2_l3', 'l3_l4', 'l4_l5', 'l5_s1']:
            test_rows.append({
                'study_id': row['study_id'],
                'condition': condition,
                'level': level
            })

X_test = pd.DataFrame(test_rows)
X_test = pd.get_dummies(X_test, columns=['condition', 'level'])
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)

# %%
X_train.head()

# %%
y_train.head()

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model

# %%
def residual_block(x, filters, kernel_size=3, stride=1, downsample=False):
    identity = x

    x = Conv2D(filters, kernel_size=kernel_size, strides=stride, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters, kernel_size=kernel_size, strides=1, padding='same')(x)
    x = BatchNormalization()(x)

    if downsample:
        identity = Conv2D(filters, kernel_size=1, strides=stride)(identity)
        identity = BatchNormalization()(identity)

    x = Add()([x, identity])
    x = Activation('relu')(x)
    return x

# %%
def build_resnet(input_shape, num_classes, num_blocks_per_stage):
    inputs = Input(shape=input_shape)
    
    # Initial Conv Layer
    x = Conv2D(64, kernel_size=7, strides=2, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=2, padding='same')(x)

    # Residual Blocks
    filters = 64
    for i, num_blocks in enumerate(num_blocks_per_stage):
        for j in range(num_blocks):
            if j == 0 and i > 0:
                x = residual_block(x, filters, downsample=True, stride=2)
            else:
                x = residual_block(x, filters)
        filters *= 2

    # Global Average Pooling and Dense Layer
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    # Create Model
    model = Model(inputs, outputs)
    return model

# %%
input_shape = (512, 512, 1)
num_classes = 3 # normal/mild, moderate, severe 
num_blocks_per_stage = [2, 2, 2, 2]  # Example for ResNet-18

model = build_resnet(input_shape, num_classes, num_blocks_per_stage)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
type(model)
keras.src.models.functional.Functional

# %%
#model = RandomForestClassifier() # dummy model, change it to nn model!!
#model.fit(X_train, y_train)
# Fit the model
history = model.fit( 
    train_generator,
    #steps_per_epoch=train_generator.samples // batch_size,
    steps_per_epoch= X_train.shape[0] // batch_size,
    validation_data=validation_generator,
    #validation_steps=validation_generator.samples // batch_size,
    validation_steps=X_test.shape[0] // batch_size,
    epochs=10  # Set the number of epochs
)

# %%
predictions_proba = model.predict_proba(X_test)
predictions_df = pd.DataFrame(predictions_proba, columns=le_severity.classes_)
predictions_df['study_id'] = X_test['study_id'].values
predictions_df['condition_level'] = X_test.index.map(lambda idx: f"{test_rows[idx]['condition']}_{test_rows[idx]['level']}")
predictions_df['row_id'] = predictions_df['study_id'].astype(str) + '_' + predictions_df['condition_level']

# %%
predictions_df

# %%
df_sub1 = pd.read_csv('/kaggle/input/rsna-2024-lumbar-spine-degenerative-classification/sample_submission.csv')

# %%
df_sub1.head()

# %%
normal_mild_value = (predictions_df['Normal/Mild'].iloc[0])
moderate_value = (predictions_df['Moderate'].iloc[0])
severe_value = (predictions_df['Severe'].iloc[0])

df_sub['normal_mild'] = normal_mild_value/2.3
df_sub['moderate'] =moderate_value*1.47
df_sub['severe'] =  (1-(normal_mild_value/2.3 +moderate_value*1.47))+severe_value-severe_value

# %%
#df_sub.sample(4)

# %%
"""
plt.figure(figsize=(14, 8))
plt.plot(df_sub['row_id'], df_sub['normal_mild'], label='Normal/Mild', marker='o')
plt.plot(df_sub['row_id'], df_sub['moderate'], label='Moderate', marker='o')
plt.plot(df_sub['row_id'], df_sub['severe'], label='Severe', marker='o')

plt.xlabel('Conditions')
plt.ylabel('Values')
plt.title('Normal/Mild, Moderate, and Severe Values for Different Conditions')
plt.xticks(rotation=90)
plt.legend()

plt.tight_layout()
plt.show() """

# %%
os.getcwd()

# %%
df_sub

# %%
df_sub.to_csv('/kaggle/working/submission.csv', index=False)

# %%
# baseline score = 1.03 #22.06.24

# %% [markdown]
# <div class="alert alert-success">
#         <h1 align="center" style="color:chocolate;">Looking Forward for feeback </h1>
#
# </div>

# %% [markdown]
# <a id="1.4"></a>
# ## <div style="box-shadow: rgba(0, 0, 0, 0.18) 0px 2px 4px inset; padding:20px; font-size:24px; font-family: consolas; text-align:center; display:fill; border-radius:15px; color:rgb(67, 66, 66)"> <b>  Refrences</b></div>

# %% [markdown]
# https://www.kaggle.com/code/josecarmona/btrc-eda-final
# https://www.kaggle.com/code/ihelon/brain-tumor-eda-with-animations-and-modeling
# https://www.kaggle.com/code/chumajin/brain-tumor-eda-for-starter-english-version

# %% [markdown]
# <div style="background-color: black; padding: 20px; border-radius: 10px; margin: 20px auto; max-width: 600px;">
#     <center>
#         <div style="background-color: white; padding: 20px; border-radius: 10px;">
#             <b style="font-size: 24px; color: #ff6600;">👏😊 &nbsp; IF YOU FIND THIS HELPFUL, PLEASE UPVOTE! &nbsp; 💢👏</b>
#             <div style="margin-top: 20px; font-size: 18px; color: black;">
#                 🥽🖥This took quite a bit of effort on my part, and while it might seem trivial, 🏆🏆receiving your appreciation means a lot to me! 😅🎃 Your upvotes inspire me to keep creating helpful content like this🖥🍱.
#             </div>
#         </div>
#     </center>
# </div>
